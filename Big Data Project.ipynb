# %%
import pymongo
import pandas as pd

# Connect to MongoDB Atlas (Replace with your URI)
client = pymongo.MongoClient("mongodb+srv://birajgtm:birajgtm@madsclass.rgddjin.mongodb.net/")

# Select the database and collection
db = client["BIG_DATA"]
collection = db["TMDB_PROCESSED"]

# %%
# Fetch data from MongoDB
data = list(collection.find({}, {"_id": 0}).limit(10))

# %%
# Convert to Pandas DataFrame
df = pd.DataFrame(data)

df.shape
# Out:
# (10, 29)

# %%
print("🔹 Sample Data from TMDB_RAW:")
# Display first few rows
df.head()
# Out:
# 🔹 Sample Data from TMDB_RAW:
#       id              name  number_of_seasons  number_of_episodes  \
# 0   1399   Game of Thrones                  8                  73
# 1  71446       Money Heist                  3                  41
# 2  66732   Stranger Things                  4                  34
# 3   1402  The Walking Dead                 11                 177
# 4  63174           Lucifer                  6                  93
#
#   original_language  vote_count  vote_average  \
# 0                en       21857         8.442
# 1                es       17836         8.257
# 2                en       16161         8.624
# 3                en       15432         8.121
# 4                en       13870         8.486
#
#                                             overview  adult  \
# 0  Seven noble families fight for control of the ...  False
# 1  To carry out the biggest heist in history, a m...  False
# 2  When a young boy vanishes, a small town uncove...  False
# ...

# %% [markdown]
# ### Preprocessing
# Remove Unnecessary Columns in MongoDB

# %%
sample_data = list(collection.find({}, {"_id": 0, "poster_path": 1, "backdrop_path": 1, "homepage": 1, "tagline": 1}).limit(10))

# Convert to DataFrame
df_before = pd.DataFrame(sample_data)

# Display the DataFrame
print("🔹 Data BEFORE Removing Unnecessary Fields:")
df_before.head(10)
# Out:
# 🔹 Data BEFORE Removing Unnecessary Fields:
#                       backdrop_path  \
# 0   /2OMB0ynKlyIenMJWI2Dy9IWT4c.jpg
# 1  /gFZriCkpJYsApPZEF3jhxL4yLzG.jpg
# 2  /2MaumbgBlW1NoPo3ZJO38A6v7OS.jpg
# 3  /x4salpjB11umlUOltfNvSSrjSXm.jpg
# 4  /aDBRtunw49UF4XmqfyNuD9nlYIu.jpg
# 5  /soQgquPkLmUu9eKLJJzuA4KZDyi.jpg
# 6  /2meX1nMdScFOoV4370rqHWKmXhY.jpg
# 7  /tsRy63Mu5cu8etL1X7ZLyf7UP1M.jpg
# 8  /xXRsKNJHTOGrs5wfYAxkbM2RiyT.jpg
# 9  /lOr9NKxh4vMweufMOUDJjJhCRHW.jpg
#
#                                             homepage  \
# 0                 http://www.hbo.com/game-of-thrones
# 1             https://www.netflix.com/title/80192098
# 2             https://www.netflix.com/title/80057281
# 3  http://www.amc.com/shows/the-walking-dead--100...
# 4             https://www.netflix.com/title/80057918
# 5               http://www.cwtv.com/shows/riverdale/
# 6             https://www.netflix.com/title/81040344
# 7              http://www.amc.com/shows/breaking-bad
# ...

# %%
# Remove unnecessary columns
update_result = collection.update_many({}, { 
    "$unset": { 
        "poster_path": 1, 
        "backdrop_path": 1, 
        "homepage": 1, 
        "tagline": 1
    } 
})

# Print update summary
print(f"Matched Documents: {update_result.matched_count}")
print(f"Modified Documents: {update_result.modified_count}")
# Out:
# ✅ Matched Documents: 169639
# ✅ Modified Documents: 169639

# %% [markdown]
# Convert Boolean Fields from string to Boolean

# %%
# Fetch sample records with boolean fields
sample_boolean_data = list(collection.find({}, {"_id": 0, "adult": 1, "in_production": 1}).limit(10))

# Convert to DataFrame
df_boolean_before = pd.DataFrame(sample_boolean_data)

# Display DataFrame before boolean conversion
print("🔹 Data BEFORE Converting Boolean Strings:")
display(df_boolean_before)
# Out:
# 🔹 Data BEFORE Converting Boolean Strings:
#    adult in_production
# 0  False         False
# 1  False         False
# 2  False          True
# 3  False         False
# 4  False         False
# 5  False         False
# 6  False          True
# 7  False         False
# 8  False          True
# 9  False         False

# %%
# Convert boolean fields in MongoDB
update_result = collection.update_many({}, [
    { "$set": { 
        "adult": { "$cond": { "if": { "$eq": ["$adult", "True"] }, "then": True, "else": False } },
        "in_production": { "$cond": { "if": { "$eq": ["$in_production", "True"] }, "then": True, "else": False } }
    }}
])

# Print update summary
print(f"✅ Matched Documents: {update_result.matched_count}")
print(f"✅ Modified Documents: {update_result.modified_count}")
# Out:
# ✅ Matched Documents: 169639
# ✅ Modified Documents: 169639

# %% [markdown]
# Convert Date Strings (first_air_date, last_air_date) to ISODate

# %%
# Fetch sample records with date fields
sample_date_data = list(collection.find({}, {"_id": 0, "first_air_date": 1, "last_air_date": 1}).limit(10))

# Convert to DataFrame
df_date_before = pd.DataFrame(sample_date_data)

# Display DataFrame before date conversion
print("🔹 Data BEFORE Converting Date Strings:")
display(df_date_before)
# Out:
# 🔹 Data BEFORE Converting Date Strings:
#   first_air_date last_air_date
# 0     2011-04-17    2019-05-19
# 1     2017-05-02    2021-12-03
# 2     2016-07-15    2022-07-01
# 3     2010-10-31    2022-11-20
# 4     2016-01-25    2021-09-10
# 5     2017-01-26    2023-08-23
# 6     2021-09-17    2021-09-17
# 7     2008-01-20    2013-09-29
# 8     2017-09-25    2023-05-01
# 9     2021-01-15    2021-03-05

# %%
# Convert date fields while handling empty values
update_result = collection.update_many(
    { "$and": [ { "first_air_date": { "$ne": "" } }, { "first_air_date": { "$exists": True } } ] },
    [{ "$set": { "first_air_date": { "$toDate": "$first_air_date" } } }]
)

update_result_2 = collection.update_many(
    { "$and": [ { "last_air_date": { "$ne": "" } }, { "last_air_date": { "$exists": True } } ] },
    [{ "$set": { "last_air_date": { "$toDate": "$last_air_date" } } }]
)

# Print update summary
print(f"✅ Matched and Modified `first_air_date`: {update_result.modified_count}")
print(f"✅ Matched and Modified `last_air_date`: {update_result_2.modified_count}")
# Out:
# ✅ Matched and Modified `first_air_date`: 135924
# ✅ Matched and Modified `last_air_date`: 137756

# %% [markdown]
#  Convert genres from a String to an Array

# %%
# Fetch sample records with genres field
sample_genres_data = list(collection.find({}, {"_id": 0, "genres": 1}).limit(10))

# Convert to DataFrame
df_genres_before = pd.DataFrame(sample_genres_data)

# Display DataFrame before conversion
print("🔹 Data BEFORE Converting `genres` to Array:")
display(df_genres_before)
# Out:
# 🔹 Data BEFORE Converting `genres` to Array:
#                                         genres
# 0  Sci-Fi & Fantasy, Drama, Action & Adventure
# 1                                 Crime, Drama
# 2             Drama, Sci-Fi & Fantasy, Mystery
# 3  Action & Adventure, Drama, Sci-Fi & Fantasy
# 4                      Crime, Sci-Fi & Fantasy
# 5                        Crime, Drama, Mystery
# 6           Action & Adventure, Mystery, Drama
# 7                                 Drama, Crime
# 8                                        Drama
# 9             Sci-Fi & Fantasy, Mystery, Drama

# %%
# Convert `genres` from string to array in MongoDB
update_result = collection.update_many({}, [
    { "$set": { 
        "genres": { 
            "$split": ["$genres", ", "]  # Split by ", " into an array
        }
    }}
])

# Print update summary
print(f"✅ Matched Documents: {update_result.matched_count}")
print(f"✅ Modified Documents: {update_result.modified_count}")
# Out:
# ✅ Matched Documents: 169639
# ✅ Modified Documents: 169639

# %% [markdown]
# Convert episode_run_time to integer and handle nulls

# %%
# Fetch sample records with episode_run_time
sample_runtime_data = list(collection.find({}, {"_id": 0, "episode_run_time": 1}).limit(10))

# Convert to DataFrame
df_runtime_before = pd.DataFrame(sample_runtime_data)

# Display DataFrame before conversion
print("🔹 Data BEFORE Converting `episode_run_time`:")
display(df_runtime_before)
# Out:
# 🔹 Data BEFORE Converting `episode_run_time`:
#    episode_run_time
# 0                 0
# 1                70
# 2                 0
# 3                42
# 4                45
# 5                45
# 6                 0
# 7                 0
# 8                43
# 9                 0

# %%
# Convert `episode_run_time` to Integer while handling nulls
update_result = collection.update_many({}, [
    { "$set": { 
        "episode_run_time": {
            "$convert": {
                "input": "$episode_run_time",
                "to": "int",
                "onError": 0,  # If not convertible, set to 0
                "onNull": 0     # If null, set to 0
            }
        }
    }}
])

# Print update summary
print(f"✅ Matched Documents: {update_result.matched_count}")
print(f"✅ Modified Documents: {update_result.modified_count}")
# Out:
# ✅ Matched Documents: 169639
# ✅ Modified Documents: 0

# %% [markdown]
# Convert vote_average to float

# %%
# Fetch sample records with vote_average
sample_vote_data = list(collection.find({}, {"_id": 0, "vote_average": 1}).limit(10))

# Convert to DataFrame
df_vote_before = pd.DataFrame(sample_vote_data)

# Display DataFrame before conversion
print("🔹 Data BEFORE Converting `vote_average`:")
display(df_vote_before)
# Out:
# 🔹 Data BEFORE Converting `vote_average`:
#    vote_average
# 0         8.442
# 1         8.257
# 2         8.624
# 3         8.121
# 4         8.486
# 5         8.479
# 6         7.831
# 7         8.890
# 8         8.503
# 9         8.300

# %%
# Convert `vote_average` to float while handling errors
update_result = collection.update_many({}, [
    { "$set": { 
        "vote_average": {
            "$convert": {
                "input": "$vote_average",
                "to": "double",  # Convert to float
                "onError": 0.0,  # If not convertible, set to 0.0
                "onNull": 0.0    # If null, set to 0.0
            }
        }
    }}
])

# Print update summary
print(f"✅ Matched Documents: {update_result.matched_count}")
print(f"✅ Modified Documents: {update_result.modified_count}")
# Out:
# ✅ Matched Documents: 169639
# ✅ Modified Documents: 0

# %% [markdown]
# Cap popularity values (Remove Outliers)

# %%
# Fetch sample records with popularity
sample_popularity_data = list(collection.find({}, {"_id": 0, "popularity": 1}).limit(10))

# Convert to DataFrame
df_popularity_before = pd.DataFrame(sample_popularity_data)

# Display DataFrame before capping
print("🔹 Data BEFORE Capping `popularity`:")
display(df_popularity_before)
# Out:
# 🔹 Data BEFORE Capping `popularity`:
#    popularity
# 0    1083.917
# 1      96.354
# 2     185.711
# 3     489.746
# 4     416.668
# 5     143.750
# 6     115.587
# 7     247.632
# 8     681.614
# 9      62.893

# %%
# Cap popularity at 5000
update_result = collection.update_many(
    { "popularity": { "$gt": 5000 } }, 
    { "$set": { "popularity": 5000 } }
)

# Print update summary
print(f"✅ Matched Documents: {update_result.matched_count}")
print(f"✅ Modified Documents: {update_result.modified_count}")
# Out:
# ✅ Matched Documents: 0
# ✅ Modified Documents: 0

# %% [markdown]
# Check and remove duplicate records

# %%
# Find duplicate records by `id`
pipeline = [
    { "$group": { "_id": "$id", "count": { "$sum": 1 }, "docs": { "$push": "$_id" } } },
    { "$match": { "count": { "$gt": 1 } } }
]

# Run aggregation query
duplicates = list(collection.aggregate(pipeline))

# Convert to DataFrame
df_duplicates = pd.DataFrame(duplicates)

# Display duplicate records if any exist
print("🔹 Duplicate Records (Grouped by `id`):")
display(df_duplicates)
# Out:
# 🔹 Duplicate Records (Grouped by `id`):
#          _id  count                                               docs
# 0      85552      2  [67e36626f93042cc55541160, 67e44727288f9c8160f...
# 1     237963      4  [67e3670bf93042cc55557f57, 67e3670ef93042cc555...
# 2     237801      4  [67e366fef93042cc5555682b, 67e36714f93042cc555...
# 3     238522      3  [67e36712f93042cc55558da4, 67e36714f93042cc555...
# 4     238760      2  [67e36761f93042cc55561069, 67e367b4f93042cc555...
# ...      ...    ...                                                ...
# 2965    1274      2  [67e36626f93042cc55541341, 67e44727288f9c8160f...
# 2966  238665      3  [67e3670bf93042cc55557ed5, 67e36714f93042cc555...
# 2967    4743      2  [67e36626f93042cc5554147d, 67e44727288f9c8160f...
# 2968   84773      2  [67e36626f93042cc555411df, 67e44727288f9c8160f...
# 2969  237956      4  [67e3670af93042cc55557a9f, 67e3670ef93042cc555...
#
# [2970 rows x 3 columns]

# %%
# Find and remove duplicates while keeping one copy
pipeline = [
    { "$group": { "_id": "$id", "docs": { "$push": "$_id" } } },
    { "$project": { "_id": 1, "keep": { "$arrayElemAt": ["$docs", 0] }, "remove": { "$slice": ["$docs", 1, { "$size": "$docs" }] } } } 
]

# Get the list of duplicate `_id`s to remove
to_remove = []
for doc in collection.aggregate(pipeline):
    to_remove.extend(doc["remove"])

# Remove duplicate records from MongoDB
if to_remove:
    delete_result = collection.delete_many({"_id": {"$in": to_remove}})
    print(f"✅ Removed {delete_result.deleted_count} duplicate records.")
else:
    print("✅ No duplicate records found.")
# Out:
# ✅ Removed 4934 duplicate records.

# %% [markdown]
# Fix Missing genres and origin_country

# %%
# Fetch records where `genres` or `origin_country` are missing or empty
missing_data = list(collection.find(
    { "$or": [ 
        { "genres": { "$exists": False } }, { "genres": [] }, { "genres": "" }, 
        { "origin_country": { "$exists": False } }, { "origin_country": [] }, { "origin_country": "" } ] 
    },
    { "_id": 0, "name": 1, "genres": 1, "origin_country": 1 }
).limit(20))  # Fetch a sample of 20 missing records

# Convert to DataFrame
df_missing = pd.DataFrame(missing_data)

# Display DataFrame
print("🔹 Records with Missing `genres` or `origin_country`:")
display(df_missing)
# Out:
# 🔹 Records with Missing `genres` or `origin_country`:
#                                                  name  \
# 0                                      Mums Make Porn
# 1                                Battlestar Galactica
# 2                                           True Love
# 3                                             Club 57
# 4                                    Pasión prohibida
# 5                                Los heroes del norte
# 6                       Hasta que la plata nos separe
# 7                          Les Contes de la rue Broca
# 8                                     Los Tres Caines
# 9                                          Doña bella
# 10                                           Escalona
# 11  My Little Pony: Equestria Girls - Better Together
# 12                                             Origin
# 13                                          Cleopatra
# 14                                         Cebollitas
# ...

# %%
# Update records where `genres` are missing or empty
update_result_genres = collection.update_many(
    { "$or": [ { "genres": { "$exists": False } }, { "genres": [] }, { "genres": "" } ] },
    { "$set": { "genres": ["No genre available"] } }
)

# Update records where `origin_country` is missing or empty
update_result_country = collection.update_many(
    { "$or": [ { "origin_country": { "$exists": False } }, { "origin_country": [] }, { "origin_country": "" } ] },
    { "$set": { "origin_country": ["No country available"] } }
)

# Print update summary
print(f"✅ Genres Fixed: {update_result_genres.modified_count}")
print(f"✅ Countries Fixed: {update_result_country.modified_count}")
# Out:
# ✅ Genres Fixed: 67226
# ✅ Countries Fixed: 31026

# %% [markdown]
# Verify Preprocessed Data

# %%
# Fetch a sample of 10 cleaned records
sample_cleaned_data = list(collection.find({}, {"_id": 0}).limit(10))

# Convert to DataFrame
df_cleaned = pd.DataFrame(sample_cleaned_data)

# Display the cleaned dataset
print("🔹 Cleaned Data Sample:")
display(df_cleaned)
# Out:
# 🔹 Cleaned Data Sample:
#       id              name  number_of_seasons  number_of_episodes  \
# 0   1399   Game of Thrones                  8                  73
# 1  71446       Money Heist                  3                  41
# 2  66732   Stranger Things                  4                  34
# 3   1402  The Walking Dead                 11                 177
# 4  63174           Lucifer                  6                  93
# 5  69050         Riverdale                  7                 137
# 6  93405        Squid Game                  2                   9
# 7   1396      Breaking Bad                  5                  62
# 8  71712   The Good Doctor                  6                 116
# 9  85271       WandaVision                  1                   9
#
#   original_language  vote_count  vote_average  \
# 0                en       21857         8.442
# 1                es       17836         8.257
# 2                en       16161         8.624
# ...

# %% [markdown]
# ### Analysis

# %% [markdown]
# 1.	 What are the top 10 highest-rated TV shows?

# %%
# Find top 10 highest-rated TV shows
top_rated_shows = list(collection.find(
    {}, 
    {"_id": 0, "name": 1, "vote_average": 1}
).sort("vote_average", -1).limit(10))

# Convert to DataFrame
df_top_rated = pd.DataFrame(top_rated_shows)

# Display the results
print("🔹 Top 10 Highest-Rated TV Shows:")
display(df_top_rated)
# Out:
# 🔹 Top 10 Highest-Rated TV Shows:
#                               name  vote_average
# 0   Scooby-Doo!: Behind the Scenes          10.0
# 1                         Delirium          10.0
# 2                           Driven          10.0
# 3                Dog's Most Wanted          10.0
# 4                      The Reaping          10.0
# 5  LOL: Last One Laughing Colombia          10.0
# 6               Teen Choice Awards          10.0
# 7                    Steel Buddies          10.0
# 8                   Dateline on ID          10.0
# 9             Tyler Perry's Zatima          10.0

# %% [markdown]
# 2.	How many TV shows are produced per country?

# %%
# Query for TV shows by country (excluding "No country available")
tv_shows_by_country_filtered = list(collection.aggregate([
    { "$match": { "origin_country": { "$nin": [["No country available"]] } } },  # Exclude missing countries
    { "$group": { "_id": "$origin_country", "count": { "$sum": 1 } } },
    { "$sort": { "count": -1 } },
    { "$limit": 10 }
]))

# Convert to DataFrame
df_shows_by_country_filtered = pd.DataFrame(tv_shows_by_country_filtered)

# Rename columns for readability
df_shows_by_country_filtered.rename(columns={"_id": "Country", "count": "Number of TV Shows"}, inplace=True)

# Display the top 10 countries excluding missing values
print("🔹 Top 10 TV Show-Producing Countries (Excluding Missing Values):")
display(df_shows_by_country_filtered)
# Out:
# 🔹 Top 10 TV Show-Producing Countries (Excluding Missing Values):
#   Country  Number of TV Shows
# 0      US               27848
# 1      JP               13393
# 2      GB               13134
# 3      CN               11039
# 4      DE                6230
# 5      KR                5998
# 6      CA                4504
# 7      FR                3899
# 8      AU                3108
# 9      BR                2505

# %% [markdown]
# 3.	What are the most common genres?

# %%
# Query for most common genres (excluding "No genre available")
popular_genres_filtered = list(collection.aggregate([
    { "$unwind": "$genres" },  # Unwind genres array
    { "$match": { "genres": { "$ne": "No genre available" } } },  # Exclude missing genres
    { "$group": { "_id": "$genres", "count": { "$sum": 1 } } },
    { "$sort": { "count": -1 } },
    { "$limit": 10 }
]))

# Convert to DataFrame
df_popular_genres_filtered = pd.DataFrame(popular_genres_filtered)

# Rename columns for readability
df_popular_genres_filtered.rename(columns={"_id": "Genre", "count": "Number of Shows"}, inplace=True)

# Display the top 10 genres excluding missing values
print("🔹 Top 10 Most Common TV Show Genres (Excluding Missing Values):")
display(df_popular_genres_filtered)
# Out:
# 🔹 Top 10 Most Common TV Show Genres (Excluding Missing Values):
#                 Genre  Number of Shows
# 0               Drama            33188
# 1              Comedy            22946
# 2         Documentary            21356
# 3           Animation            11829
# 4             Reality            10755
# 5  Action & Adventure             7200
# 6               Crime             6754
# 7              Family             6359
# 8    Sci-Fi & Fantasy             6298
# 9             Mystery             5198

# %% [markdown]
# Fetch and Export Cleaned Data to CSV

# %%
# Fetch cleaned data
cleaned_data = list(collection.find({}, {"_id": 0}))  # Exclude `_id` field

# Convert to DataFrame
df_cleaned = pd.DataFrame(cleaned_data)

# Define CSV file path
csv_file_path = "/Users/birajgtm/Documents/GBC/AI/TMDB_Cleaned_Data.csv"

# Save DataFrame as CSV
df_cleaned.to_csv(csv_file_path, index=False)

print(f"✅ Data exported successfully to: {csv_file_path}")
# Out:
# ✅ Data exported successfully to: /Users/birajgtm/Documents/GBC/AI/TMDB_Cleaned_Data.csv

# %%
# Define CSV file path
csv_file_path = "/Users/birajgtm/Documents/GBC/AI/TMDB_Cleaned_Data.csv"

# Load CSV into DataFrame
df_csv = pd.read_csv(csv_file_path)

# Display first few rows of the CSV data
print("🔹 Preview of TMDB Cleaned Data:")
display(df_csv.head())
# Out:
# 🔹 Preview of TMDB Cleaned Data:
#       id              name  number_of_seasons  number_of_episodes  \
# 0   1399   Game of Thrones                  8                  73
# 1  71446       Money Heist                  3                  41
# 2  66732   Stranger Things                  4                  34
# 3   1402  The Walking Dead                 11                 177
# 4  63174           Lucifer                  6                  93
#
#   original_language  vote_count  vote_average  \
# 0                en       21857         8.442
# 1                es       17836         8.257
# 2                en       16161         8.624
# 3                en       15432         8.121
# 4                en       13870         8.486
#
#                                             overview  adult  \
# 0  Seven noble families fight for control of the ...  False
# 1  To carry out the biggest heist in history, a m...  False
# 2  When a young boy vanishes, a small town uncove...  False
# ...
